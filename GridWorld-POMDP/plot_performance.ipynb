# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# shape:o, actu:[0.00, 0.05, 0.10, 0.15, 0.20], sens:0
result00 = [
    -13817.077530,
    -9274.596367,
    -6143.651323,
    -3691.055693,
    -1688.081712,
    -819.015138,
    -1.363573,
    -2.888510,
    -1.739481,
    -1.112093,
    -2.141828,
    -1.711622,
    -1.440954,
    -1.349989,
]
result05 = [
    -14118.857175,
    -10024.086877,
    -8623.152806,
    -5269.622153,
    -4368.492035,
    -2425.655322,
    -1575.628988,
    -1571.552943,
    -2418.667823,
    -1558.533939,
    -1559.951660,
    -1552.696524,
    -1555.001750,
    -1551.907348,
]
result10 = [
    -14264.152922,
    -10573.387020,
    -9289.412629,
    -6209.118263,
    -5499.486290,
    -3488.254398,
    -3475.653326,
    -2644.777475,
    -3466.680432,
    -2640.037846,
    -2626.050233,
    -2634.788299,
    -2617.537734,
    -2604.328349,
]
result15 = [
    -14583.173696,
    -10997.991049,
    -8835.517493,
    -7077.309317,
    -5371.020228,
    -4472.678214,
    -3638.723137,
    -3627.009549,
    -3630.117176,
    -3616.215416,
    -3615.240396,
    -3613.017504,
    -3606.574383,
    -3594.966897,
]
result20 = [
    -14656.541812,
    -11498.539598,
    -9633.119346,
    -7986.991037,
    -6402.527352,
    -5512.839929,
    -4676.795904,
    -4665.405810,
    -4656.015626,
    -4655.685365,
    -4641.547003,
    -4639.146490,
    -4634.888218,
    -4630.726692,
]

xvalues = list(range(2, 2 + len(result00)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result00, 'b^-', linewidth=2, markersize=6, label='prob=0.00')
plt.plot(xvalues, result05, 'g^-', linewidth=2, markersize=6, label='prob=0.05')
plt.plot(xvalues, result10, 'r^-', linewidth=2, markersize=6, label='prob=0.10')
plt.plot(xvalues, result15, 'c^-', linewidth=2, markersize=6, label='prob=0.15')
plt.plot(xvalues, result20, 'k^-', linewidth=2, markersize=6, label='prob=0.20')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-16000, 1000])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:o, actu:0, sens:[0.02, 0.04, 0.06, 0.08, 0.10]
result02 = [
    -17102.771459,
    -12875.583568,
    -9722.867271,
    -7577.030156,
    -6717.435895,
    -4718.183097,
    -3861.611463,
    -3859.180033,
    -4710.328504,
    -3853.138204,
    -3834.517612,
    -3845.073499,
    -3832.704183,
    -3840.195656,
]
result04 = [
    -19328.025597,
    -15330.281034,
    -13898.016652,
    -10445.661114,
    -9671.513452,
    -8518.783509,
    -6821.365946,
    -6820.386098,
    -6808.005059,
    -6798.781087,
    -6804.544172,
    -6798.278071,
    -6800.479238,
    -6788.475664,
]
result06 = [
    -20749.170662,
    -16889.584286,
    -15535.042419,
    -12368.249475,
    -12144.097169,
    -9711.239138,
    -8877.601212,
    -8870.736029,
    -9693.143335,
    -8860.317432,
    -8847.068541,
    -8845.574920,
    -8841.010709,
    -8840.714928,
]
result08 = [
    -22085.023332,
    -18679.966714,
    -16367.488805,
    -14516.473076,
    -12798.996794,
    -11953.365286,
    -11136.787269,
    -11133.364106,
    -11121.160683,
    -11117.687391,
    -11119.924943,
    -11102.224333,
    -11087.751853,
    -11092.598727,
]
result10 = [
    -23043.757969,
    -19934.653811,
    -18834.922781,
    -16168.393522,
    -14633.473555,
    -13841.420364,
    -13010.190733,
    -12996.349734,
    -12991.899173,
    -12982.756233,
    -12955.494722,
    -12963.195876,
    -12956.444478,
    -12955.644866,
]

xvalues = list(range(2, 2 + len(result00)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result02, 'b^-', linewidth=2, markersize=6, label='prob=0.02 (0.07)')
plt.plot(xvalues, result04, 'g^-', linewidth=2, markersize=6, label='prob=0.04 (0.15)')
plt.plot(xvalues, result06, 'r^-', linewidth=2, markersize=6, label='prob=0.06 (0.21)')
plt.plot(xvalues, result08, 'c^-', linewidth=2, markersize=6, label='prob=0.08 (0.28)')
plt.plot(xvalues, result10, 'k^-', linewidth=2, markersize=6, label='prob=0.10 (0.34)')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-24000, 0])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:o, actu-sens:[0.05-0.02, 0.10-0.04, 0.15-0.06, 0.20-0.08, 0.25-0.10]
result05_02 = [
    -17233.018199,  # 2 states
    -13351.706401,  # 3 states
    -10728.346778,  # 4 states
    -8698.833360,  # 5 states
    -7851.064148,  # 6 states
    -6006.266579,  # 7 states
    -5193.942464,  # 8 states
    -5187.338127,  # 9 states
    -5181.153599,  # 10 states
    -5160.885610,  # 11 states
    -5151.280479,  # 12 states
    -5148.021088,  # 13 states
    -5136.753431,  # 14 states
    -5121.082291,  # 15 states
]
result10_04 = [
    -19601.973144,  # 2 states
    -16290.495365,  # 3 states
    -14296.626498,  # 4 states
    -12455.878695,  # 5 states
    -10905.188339,  # 6 states
    -10044.967747,  # 7 states
    -9229.491851,  # 8 states
    -9215.967155,  # 9 states
    -9205.832974,  # 10 states
    -9193.823907,  # 11 states
    -9182.478365,  # 12 states
    -9159.588249,  # 13 states
    -9163.989817,  # 14 states
    -9136.254242,  # 15 states
]
result15_06 = [
    -21180.141873,  # 2 states
    -18388.949934,  # 3 states
    -16598.258826,  # 4 states
    -15140.628953,  # 5 states
    -13851.904316,  # 6 states
    -13022.589708,  # 7 states
    -12228.850370,  # 8 states
    -13006.427956,  # 9 states
    -12197.038515,  # 10 states
    -12188.315491,  # 11 states
    -12160.349785,  # 12 states
    -12160.292765,  # 13 states
    -12140.207360,  # 14 states
    -12108.836304,  # 15 states
]
result20_08 = [
    -22501.659474,  # 2 states
    -20139.094732,  # 3 states
    -18757.184548,  # 4 states
    -17477.715378,  # 5 states
    -16355.431316,  # 6 states
    -15595.624149,  # 7 states
    -14839.500910,  # 8 states
    -14822.201463,  # 9 states
    -14806.454682,  # 10 states
    -14771.523346,  # 11 states
    -14758.927434,  # 12 states
    -14735.643423,  # 13 states
    -14720.748780,  # 14 states
    -14689.894397,  # 15 states
]
result25_10 = [
    -23471.778864,  # 2 states
    -21591.845276,  # 3 states
    -20575.636341,  # 4 states
    -19518.928003,  # 5 states
    -18555.146929,  # 6 states
    -17849.254382,  # 7 states
    -17146.244949,  # 8 states
    -17128.055277,  # 9 states
    -17122.492638,  # 10 states
    -17096.337101,  # 11 states
    -17061.974565,  # 12 states
    -17057.023609,  # 13 states
    -17024.804024,  # 14 states
    -16988.706175,  # 15 states
]

xvalues = list(range(2, 2 + len(result20_08)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result05_02, 'b^-', linewidth=2, markersize=6, label='s=0.05, a=0.02')
plt.plot(xvalues, result10_04, 'g^-', linewidth=2, markersize=6, label='s=0.10, a=0.04')
plt.plot(xvalues, result15_06, 'r^-', linewidth=2, markersize=6, label='s=0.15, a=0.06')
plt.plot(xvalues, result20_08, 'c^-', linewidth=2, markersize=6, label='s=0.20, a=0.08')
plt.plot(xvalues, result25_10, 'k^-', linewidth=2, markersize=6, label='s=0.25, a=0.10')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-28000, -4000])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:sharp, actu-sens:[0.00-0.00, 0.05-0.02, 0.10-0.04, 0.15-0.06, 0.20-0.08, 0.25-0.10]
result00_00 = [
    -18448.133443,
    -16270.467059,
    -13818.539399,
    -11294.712059,
    -8588.247718,
    -6850.989348,
    -4764.318384,
    -3669.664980,
    -2511.752892,
    -565.877132,
    -2.033385,
    -572.989864,
    -567.335505,
    -2.818989,
    -2.728689,  # 16 states
    -2.566016,  # 17 states
]
result05_02 = [
    -21308.375451,  # 2 states
    -18098.568115,  # 3 states
    -16567.303449,  # 4 states
    -14038.997852,  # 5 states
    -12960.869815,  # 6 states
    -11184.049684,  # 7 states
    -9369.184507,  # 8 states
    -8401.528679,  # 9 states
    -6533.571991,  # 10 states
    -6526.311262,  # 11 states
    -5986.195161,  # 12 states
    -5968.968081,  # 13 states
    -5400.686482,  # 14 states
    -5395.221452,  # 15 states
    -5383.226181,  # 16 states
    -5373.030454,  # 17 states
]
result10_04 = [
    -22527.036758,  # 2 states
    -19964.306513,  # 3 states
    -18473.047646,  # 4 states
    -17040.379272,  # 5 states
    -15759.911277,  # 6 states
    -14570.216900,  # 7 states
    -12690.959427,  # 8 states
    -11619.599236,  # 9 states
    -10939.710401,  # 10 states
    -9778.031073,  # 11 states
    -9174.126058,  # 12 states
    -9762.320458,  # 13 states
    -9144.019310,  # 14 states
    -9133.867373,  # 15 states
    -9121.047019,  # 16 states
    -9112.302480,  # 17 states
]
result15_06 = [
    -23316.641393,  # 2 states
    -21638.741432,  # 3 states
    -20080.027297,  # 4 states
    -18690.339632,  # 5 states
    -17813.460009,  # 6 states
    -16735.758585,  # 7 states
    -15385.480961,  # 8 states
    -14570.631885,  # 9 states
    -13203.640464,  # 10 states
    -12687.655452,  # 11 states
    -12681.276976,  # 12 states
    -12185.187830,  # 13 states
    -12182.013968,  # 14 states
    -12162.260021,  # 15 states
    -12141.363033,  # 16 states
    -12118.696884,  # 17 states
]
result20_08 = [
    -24034.321003,  # 2 states
    -22651.847318,  # 3 states
    -21642.865385,  # 4 states
    -20409.602664,  # 5 states
    -19407.722496,  # 6 states
    -18599.138081,  # 7 states
    -17516.001589,  # 8 states
    -16972.144995,  # 9 states
    -16516.480232,  # 10 states
    -15203.224700,  # 11 states
    -14719.462197,  # 12 states
    -15175.111546,  # 13 states
    -14682.794136,  # 14 states
    -14666.414712,  # 15 states
    -14645.437173,  # 16 states
    -14619.360685,  # 17 states
]
result25_10 = [
    -24935.265800,  # 2 states
    -23734.171950,  # 3 states
    -22713.820304,  # 4 states
    -21706.604378,  # 5 states
    -20967.350311,  # 6 states
    -20250.268943,  # 7 states
    -19379.501401,  # 8 states
    -18635.427860,  # 9 states
    -18048.903633,  # 10 states
    -17610.649369,  # 11 states
    -17158.799521,  # 12 states
    -17130.723979,  # 13 states
    -17120.196709,  # 14 states
    -17096.179625,  # 15 states
    -17087.592748,  # 16 states
    -17059.400718,  # 17 states
]

xvalues = list(range(2, 2 + len(result20_08)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result00_00, 'b^-', linewidth=2, markersize=6, label='s=0.00, a=0.00')
plt.plot(xvalues, result05_02, 'g^-', linewidth=2, markersize=6, label='s=0.05, a=0.02')
plt.plot(xvalues, result10_04, 'r^-', linewidth=2, markersize=6, label='s=0.10, a=0.04')
plt.plot(xvalues, result15_06, 'c^-', linewidth=2, markersize=6, label='s=0.15, a=0.06')
plt.plot(xvalues, result20_08, 'm^-', linewidth=2, markersize=6, label='s=0.20, a=0.08')
plt.plot(xvalues, result25_10, 'k^-', linewidth=2, markersize=6, label='s=0.25, a=0.10')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-33000, 1000])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:eight, actu:[0.00, 0.05, 0.10, 0.15, 0.20, 0.25], sens:0
result00 = [
    -12764.545748,  # 2 states
    -9727.126050,  # 3 states
    -7314.552868,  # 4 states
    -6500.547304,  # 5 states
    -5032.238460,  # 6 states
    -4124.319309,  # 7 states
    -3216.806412,  # 8 states
    -3127.183934,  # 9 states
    -2614.122914,  # 10 states
    -2171.647556,  # 11 states
    -1511.172536,  # 12 states
    -1379.895667,  # 13 states
    -1511.539428,  # 14 states
    -977.682528,  # 15 states
    -983.489053,  # 16 states
    -1121.695138,  # 17 states
    -873.992569,  # 18 states
    -870.457609,  # 19 states
    -925.524279,  # 20 states
    -492.526508,  # 21 states
    -502.167042,  # 22 states
    -294.690956,  # 23 states
    -239.407741,  # 24 states
    -532.993810,  # 25 states
]
result05 = [
    -12937.017023,  # 2 states
    -10106.066032,  # 3 states
    -7944.001528,  # 4 states
    -6903.525399,  # 5 states
    -6079.515341,  # 6 states
    -5329.642185,  # 7 states
    -4863.856492,  # 8 states
    -4274.746286,  # 9 states
    -3707.720145,  # 10 states
    -3367.779868,  # 11 states
    -3249.568627,  # 12 states
    -2866.416329,  # 13 states
    -2664.544500,  # 14 states
    -2653.023834,  # 15 states
    -2391.902096,  # 16 states
    -2215.218322,  # 17 states
    -1867.438599,  # 18 states
    -1860.639523,  # 19 states
    -2005.854671,  # 20 states
    -1623.895162,  # 21 states
    -1821.742532,  # 22 states
    -1850.173819,  # 23 states
    -1543.851546,  # 24 states
    -1435.950902,  # 25 states
]
result10 = [
    -13422.578504,  # 2 states
    -10736.871466,  # 3 states
    -8570.859565,  # 4 states
    -7757.156573,  # 5 states
    -6983.867877,  # 6 states
    -6377.518709,  # 7 states
    -5882.969566,  # 8 states
    -5352.014115,  # 9 states
    -4943.470224,  # 10 states
    -4453.454041,  # 11 states
    -4512.508569,  # 12 states
    -3840.495344,  # 13 states
    -3957.834125,  # 14 states
    -3441.496468,  # 15 states
    -3347.638725,  # 16 states
    -3170.180174,  # 17 states
    -2971.029981,  # 18 states
    -2948.879141,  # 19 states
    -2867.577557,  # 20 states
    -2799.764997,  # 21 states
    -2835.228861,  # 22 states
    -2588.795625,  # 23 states
    -2573.330601,  # 24 states
    -2571.508770,  # 25 states
]
result15 = [
    -12910.618879,  # 2 states
    -10571.329869,  # 3 states
    -8798.868240,  # 4 states
    -8066.073278,  # 5 states
    -7454.124670,  # 6 states
    -6921.777625,  # 7 states
    -6292.756454,  # 8 states
    -5833.233032,  # 9 states
    -5622.721084,  # 10 states
    -5255.452113,  # 11 states
    -4941.540086,  # 12 states
    -4780.017649,  # 13 states
    -4716.274454,  # 14 states
    -4574.959560,  # 15 states
    -4274.294544,  # 16 states
    -4201.815777,  # 17 states
    -3803.528474,  # 18 states
    -3746.397744,  # 19 states
    -3622.884902,  # 20 states
    -3711.173946,  # 21 states
    -3515.101877,  # 22 states
    -3426.158106,  # 23 states
    -3461.124226,  # 24 states
    -3442.353030,  # 25 states
]
result20 = [
    -13436.528893,  # 2 states
    -11285.541773,  # 3 states
    -9448.050952,  # 4 states
    -8687.195615,  # 5 states
    -8008.474693,  # 6 states
    -7538.756871,  # 7 states
    -6993.091537,  # 8 states
    -6508.655197,  # 9 states
    -6373.519104,  # 10 states
    -6080.480942,  # 11 states
    -5661.733129,  # 12 states
    -5365.901259,  # 13 states
    -5199.971982,  # 14 states
    -4816.433079,  # 15 states
    -4760.486568,  # 16 states
    -4844.627170,  # 17 states
    -4591.431825,  # 18 states
    -4420.407047,  # 19 states
    -4621.758787,  # 20 states
    -4464.051274,  # 21 states
    -4275.821403,  # 22 states
    -4316.146564,  # 23 states
    -4173.684204,  # 24 states
    -4042.209281,  # 25 states
]
result25 = [
    -13147.450973,  # 2 states
    -11032.174962,  # 3 states
    -9422.655962,  # 4 states
    -8754.810421,  # 5 states
    -8124.068279,  # 6 states
    -7755.196959,  # 7 states
    -7371.197353,  # 8 states
    -6872.915699,  # 9 states
    -6318.042821,  # 10 states
    -6362.616760,  # 11 states
    -6099.774714,  # 12 states
    -5963.578942,  # 13 states
    -5449.756646,  # 14 states
    -5591.933763,  # 15 states
    -5244.576223,  # 16 states
    -5240.860071,  # 17 states
    -5272.958074,  # 18 states
    -4844.217325,  # 19 states
    -4801.292992,  # 20 states
    -4778.562355,  # 21 states
    -4789.320734,  # 22 states
    -4840.892469,  # 23 states
    -4798.456513,  # 24 states
    -4782.059204,  # 25 states
]


xvalues = list(range(2, 2 + len(result25)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result00, 'b^-', linewidth=2, markersize=6, label='prob=0.00')
plt.plot(xvalues, result05, 'g^-', linewidth=2, markersize=6, label='prob=0.05')
plt.plot(xvalues, result10, 'r^-', linewidth=2, markersize=6, label='prob=0.10')
plt.plot(xvalues, result15, 'c^-', linewidth=2, markersize=6, label='prob=0.15')
plt.plot(xvalues, result20, 'm^-', linewidth=2, markersize=6, label='prob=0.20')
plt.plot(xvalues, result25, 'k^-', linewidth=2, markersize=6, label='prob=0.25')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-14000, 500])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:eight, actu:0, sens:[0.02, 0.04, 0.06, 0.08, 0.10]
result02 = [
    -15641.740396,  # 2 states
    -13063.498273,  # 3 states
    -10607.698731,  # 4 states
    -9389.066986,  # 5 states
    -8560.752430,  # 6 states
    -7549.861696,  # 7 states
    -7058.235307,  # 8 states
    -6889.831559,  # 9 states
    -6132.965970,  # 10 states
    -5971.594064,  # 11 states
    -5843.131720,  # 12 states
    -5436.836982,  # 13 states
    -5105.725931,  # 14 states
    -5117.283658,  # 15 states
    -4483.027745,  # 16 states
    -4696.469574,  # 17 states
    -4704.689005,  # 18 states
    -4562.908970,  # 19 states
    -4321.149739,  # 20 states
    -4478.976651,  # 21 states
    -3866.147674,  # 22 states
    -4130.994415,  # 23 states
    -4284.313672,  # 24 states
    -3850.243916,  # 25 states
]
result04 = [
    -17476.459596,  # 2 states
    -15020.312785,  # 3 states
    -12950.698629,  # 4 states
    -11842.095816,  # 5 states
    -10985.145121,  # 6 states
    -10000.168900,  # 7 states
    -10212.977362,  # 8 states
    -9177.522217,  # 9 states
    -8855.024370,  # 10 states
    -8475.568171,  # 11 states
    -8556.265963,  # 12 states
    -8079.710695,  # 13 states
    -8185.204329,  # 14 states
    -7569.797975,  # 15 states
    -7789.549021,  # 16 states
    -7684.777513,  # 17 states
    -7387.003115,  # 18 states
    -7429.728463,  # 19 states
    -7435.372074,  # 20 states
    -7687.987742,  # 21 states
    -7200.053672,  # 22 states
    -7022.835545,  # 23 states
    -7135.300721,  # 24 states
    -6991.917407,  # 25 states
]
result06 = [
    -18934.340228,  # 2 states
    -16859.462157,  # 3 states
    -14852.759431,  # 4 states
    -13870.719498,  # 5 states
    -13160.015498,  # 6 states
    -12226.017273,  # 7 states
    -11920.548591,  # 8 states
    -11223.491432,  # 9 states
    -10914.394140,  # 10 states
    -11127.996127,  # 11 states
    -10657.447982,  # 12 states
    -10441.601976,  # 13 states
    -10317.847157,  # 14 states
    -9848.638191,  # 15 states
    -9848.529126,  # 16 states
    -9789.238900,  # 17 states
    -9562.504106,  # 18 states
    -9575.666800,  # 19 states
    -9584.399865,  # 20 states
    -9547.525763,  # 21 states
    -9652.734828,  # 22 states
    -9572.804091,  # 23 states
    -9205.578122,  # 24 states
    -9346.134529,  # 25 states
]
result08 = [
    -20019.779416,  # 2 states
    -18166.484004,  # 3 states
    -16487.580838,  # 4 states
    -15542.881799,  # 5 states
    -14845.338015,  # 6 states
    -14004.853058,  # 7 states
    -13840.386406,  # 8 states
    -13116.028116,  # 9 states
    -12796.134593,  # 10 states
    -12483.277976,  # 11 states
    -12526.351702,  # 12 states
    -12052.658014,  # 13 states
    -12053.787086,  # 14 states
    -11687.333987,  # 15 states
    -11984.810615,  # 16 states
    -11990.190111,  # 17 states
    -11792.569828,  # 18 states
    -11722.327580,  # 19 states
    -11469.661329,  # 20 states
    -11463.376583,  # 21 states
    -11346.072441,  # 22 states
    -11347.409728,  # 23 states
    -11482.155616,  # 24 states
    -11356.855104,  # 25 states
]
result10 = [
    -21330.172781,  # 2 states
    -19669.716020,  # 3 states
    -18183.526359,  # 4 states
    -17291.634947,  # 5 states
    -16677.080627,  # 6 states
    -15799.976270,  # 7 states
    -15754.919085,  # 8 states
    -15038.948986,  # 9 states
    -14857.341111,  # 10 states
    -14463.083635,  # 11 states
    -14384.147190,  # 12 states
    -14222.904231,  # 13 states
    -14081.557063,  # 14 states
    -13758.815973,  # 15 states
    -13978.141552,  # 16 states
    -14060.573388,  # 17 states
    -13896.854134,  # 18 states
    -13831.215094,  # 19 states
    -13704.888390,  # 20 states
    -13857.569601,  # 21 states
    -13666.548389,  # 22 states
    -13589.165359,  # 23 states
    -13562.670983,  # 24 states
    -13387.553170,  # 25 states
]

xvalues = list(range(2, 2 + len(result02)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result02, 'b^-', linewidth=2, markersize=6, label='prob=0.02 (0.07)')
plt.plot(xvalues, result04, 'g^-', linewidth=2, markersize=6, label='prob=0.04 (0.15)')
plt.plot(xvalues, result06, 'r^-', linewidth=2, markersize=6, label='prob=0.06 (0.21)')
plt.plot(xvalues, result08, 'c^-', linewidth=2, markersize=6, label='prob=0.08 (0.28)')
plt.plot(xvalues, result10, 'k^-', linewidth=2, markersize=6, label='prob=0.10 (0.34)')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-24000, -3000])
matplotlib.rcParams.update({'font.size': 10})
plt.show()

# %%
# shape:eight, actu-sens:[0.05-0.02, 0.10-0.04, 0.15-0.06, 0.20-0.08, 0.25-0.10]
result05_02 = [
    -15886.493136,  # 2 states
    -13648.212896,  # 3 states
    -11385.336733,  # 4 states
    -10539.003916,  # 5 states
    -9738.874170,  # 6 states
    -8993.510759,  # 7 states
    -8523.024400,  # 8 states
    -8033.623265,  # 9 states
    -7368.618012,  # 10 states
    -7262.000769,  # 11 states
    -7378.779519,  # 12 states
    -6902.731182,  # 13 states
    -6856.049010,  # 14 states
    -6321.077686,  # 15 states
    -6227.577399,  # 16 states
    -6368.329271,  # 17 states
    -6110.347537,  # 18 states
    -6080.614014,  # 19 states
    -6216.885312,  # 20 states
    -5743.185332,  # 21 states
    -5788.136679,  # 22 states
    -5592.316137,  # 23 states
    -5722.450783,  # 24 states
    -5478.117353,  # 25 states
]
result10_04 = [
    -17744.880047,  # 2 states
    -15787.208851,  # 3 states
    -14048.291506,  # 4 states
    -13451.826283,  # 5 states
    -12873.431760,  # 6 states
    -12340.310436,  # 7 states
    -12040.516711,  # 8 states
    -11487.090426,  # 9 states
    -11092.153324,  # 10 states
    -10761.843738,  # 11 states
    -10757.778548,  # 12 states
    -10366.799654,  # 13 states
    -10338.786015,  # 14 states
    -10107.600211,  # 15 states
    -10519.464443,  # 16 states
    -10096.067225,  # 17 states
    -9939.917896,  # 18 states
    -9764.386223,  # 19 states
    -9764.661868,  # 20 states
    -9545.266525,  # 21 states
    -9626.472384,  # 22 states
    -9611.235541,  # 23 states
    -9605.176955,  # 24 states
    -9651.607282,  # 25 states
]
result15_06 = [
    -19034.559280,  # 2 states
    -17493.922393,  # 3 states
    -16026.456604,  # 4 states
    -15409.280894,  # 5 states
    -15156.039748,  # 6 states
    -14697.076383,  # 7 states
    -14269.331043,  # 8 states
    -14014.436526,  # 9 states
    -13469.313766,  # 10 states
    -13493.088952,  # 11 states
    -13500.490039,  # 12 states
    -12988.722983,  # 13 states
    -13027.877816,  # 14 states
    -13003.971753,  # 15 states
    -12598.813530,  # 16 states
    -12627.574627,  # 17 states
    -12706.972216,  # 18 states
    -12549.439257,  # 19 states
    -12596.009751,  # 20 states
    -12333.950814,  # 21 states
    -12162.111987,  # 22 states
    -12452.924720,  # 23 states
    -12351.354199,  # 24 states
    -12087.754394,  # 25 states
]
result20_08 = [
    -20425.552903,  # 2 states
    -19180.406357,  # 3 states
    -17963.813404,  # 4 states
    -17516.009652,  # 5 states
    -16994.371634,  # 6 states
    -16717.540299,  # 7 states
    -16565.328027,  # 8 states
    -16216.355381,  # 9 states
    -15838.965365,  # 10 states
    -15782.083590,  # 11 states
    -15792.952826,  # 12 states
    -15657.118161,  # 13 states
    -15470.934640,  # 14 states
    -15295.493166,  # 15 states
    -15290.377577,  # 16 states
    -15145.985547,  # 17 states
    -15218.507649,  # 18 states
    -15200.793300,  # 19 states
    -14981.439186,  # 20 states
    -15161.529635,  # 21 states
    -15029.684088,  # 22 states
    -14941.835096,  # 23 states
    -14934.187481,  # 24 states
    -15126.366852,  # 25 states
]
result25_10 = [
    -21183.854266,  # 2 states
    -20289.361283,  # 3 states
    -19268.000581,  # 4 states
    -18902.015305,  # 5 states
    -18678.914068,  # 6 states
    -18315.841154,  # 7 states
    -18227.949121,  # 8 states
    -17797.228611,  # 9 states
    -17930.112734,  # 10 states
    -17574.576842,  # 11 states
    -17666.597759,  # 12 states
    -17458.471356,  # 13 states
    -17545.309937,  # 14 states
    -17516.394610,  # 15 states
    -17303.864471,  # 16 states
    -17279.562251,  # 17 states
    -17258.779090,  # 18 states
    -17170.838686,  # 19 states
    -17108.132474,  # 20 states
    -17005.154419,  # 21 states
    -16952.831435,  # 22 states
    -17094.622539,  # 23 states
    -17106.892101,  # 24 states
    -17096.820658,  # 25 states
]

xvalues = list(range(2, 2 + len(result20_08)))

fig = plt.figure(figsize=(8, 3.5))
#plt.yscale('log')
plt.plot(xvalues, result05_02, 'b^-', linewidth=2, markersize=6, label='s=0.05, a=0.02')
plt.plot(xvalues, result10_04, 'g^-', linewidth=2, markersize=6, label='s=0.10, a=0.04')
plt.plot(xvalues, result15_06, 'r^-', linewidth=2, markersize=6, label='s=0.15, a=0.06')
plt.plot(xvalues, result20_08, 'c^-', linewidth=2, markersize=6, label='s=0.20, a=0.08')
plt.plot(xvalues, result25_10, 'k^-', linewidth=2, markersize=6, label='s=0.25, a=0.10')
plt.xlabel('Number of latent states')
plt.ylabel('Log likelihood')
plt.legend(loc='best', ncol=2)
plt.grid()
plt.ylim([-28000, -5000])
matplotlib.rcParams.update({'font.size': 10})
plt.show()
