# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# q learning, response rate
txt2 = [
    0.6743801653,
    0.8405612245,
    0.9289544236,
    0.9293628809,
    0.9047619048,
    0.9426229508,
    0.9090909091,
    0.9205378973,
    0.855163728,
    0.9559613319,
]
txt4 = [
    0.7423312883,
    0.8005502063,
    0.8826666667,
    0.8575305292,
    0.9043824701,
    0.8194444444,
    0.928665786,
    0.9016990291,
    0.9456118665,
    0.9622395833,
]
txt5 = [
    0.8148760331,
    0.9083447332,
    0.9613402062,
    0.946251768,
    0.9154557464,
    0.9134751773,
    0.9149232915,
    0.9411764706,
    0.942812983,
    0.9193776521,
]
txt6 = [
    0.6890034364,
    0.8358208955,
    0.8473895582,
    0.8848641656,
    0.95,
    0.9504249292,
    0.8411689962,
    0.953164557,
    0.9531066823,
    0.9497354497,
]

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), txt2, 'go--', linewidth=2, markersize=6, label='User 1')
plt.plot(list(range(1, 11)), txt4, 'rs-', linewidth=2, markersize=6, label='User 2')
plt.plot(list(range(1, 11)), txt5, 'b^:', linewidth=2, markersize=8, label='User 3')
plt.plot(list(range(1, 11)), txt6, 'k*-.', linewidth=2, markersize=8, label='User 4')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Response rate')
plt.ylim([0.6, 1.00])
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.axhline(y=0.77, color='k', linestyle='--')
plt.text(4.2, 0.74, "Baseline, y=0.77", fontsize=12)
plt.show()
fig.savefig("export_figures/response_rate_qlearning.pdf", bbox_inches='tight')

# %%
# contextual bandit, response rate
txt2 = [
    0.733044733,
    0.65,
    0.6947082768,
    0.8435828877,
    0.9307909605,
    0.9003516999,
    0.7735148515,
    0.9077490775,
    0.9077490775,
    0.7929354446,
]

txt4 = [
    0.875,
    0.8719211823,
    0.9529120198,
    0.950744559,
    0.9116607774,
    0.8629943503,
    0.9210206561,
    1,
    0.8848484848,
    0.9480369515,
]

txt5 = [
    0.7407407407,
    0.8773448773,
    0.932705249,
    0.899204244,
    0.8676470588,
    0.8052631579,
    0.8333333333,
    0.8445945946,
    0.8188010899,
    0.8665768194,
]

txt6 = [
    0.7333333333,
    0.8285714286,
    0.8551980198,
    0.6811023622,
    0.7642956764,
    0.7258064516,
    0.8354037267,
    0.8838709677,
    0.7771952818,
    0.9053333333,
]

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), txt2, 'go--', linewidth=2, markersize=6, label='User 1')
plt.plot(list(range(1, 11)), txt4, 'rs-', linewidth=2, markersize=6, label='User 2')
plt.plot(list(range(1, 11)), txt5, 'b^:', linewidth=2, markersize=8, label='User 3')
plt.plot(list(range(1, 11)), txt6, 'k*-.', linewidth=2, markersize=8, label='User 4')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Response rate')
plt.ylim([0.6, 1.00])
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.axhline(y=0.77, color='k', linestyle='--')
plt.text(7.7, 0.74, "Baseline, y=0.77", fontsize=12)
plt.show()
fig.savefig("export_figures/response_rate_contextual_bandit.pdf", bbox_inches='tight')

# %%
# q-learning, number of notifications
txt2 = np.array([
    213,
    88,
    75,
    79,
    75,
    72,
    80,
    77,
    78,
    73,
])

txt4 = np.array([
    250,
    110,
    80,
    76,
    69,
    77,
    74,
    74,
    68,
    69,
])

txt5 = np.array([
    268,
    119,
    134,
    133,
    140,
    132,
    131,
    119,
    136,
    123,
])

txt6 = np.array([
    227,
    100,
    79,
    79,
    79,
    85,
    80,
    81,
    75,
    78,
])

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), txt2 / 7., 'go--', linewidth=2, markersize=6, label='User 1')
plt.plot(list(range(1, 11)), txt4 / 7., 'rs-', linewidth=2, markersize=6, label='User 2')
plt.plot(list(range(1, 11)), txt5 / 7., 'b^:', linewidth=2, markersize=8, label='User 3')
plt.plot(list(range(1, 11)), txt6 / 7., 'k*-.', linewidth=2, markersize=8, label='User 4')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Daily notifications')
plt.ylim([0, 45])
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.axhline(y=17.8, color='k', linestyle='--')
plt.text(4.1, 14.3, "Baseline, y=17.8", fontsize=12)
plt.show()
fig.savefig("export_figures/num_notification_qlearning.pdf", bbox_inches='tight')

# %%
# contextual bandit, num notifications
txt2 = np.array([
    65,
    27,
    80,
    103,
    82,
    82,
    104,
    80,
    80,
    106,
])

txt4 = np.array([
    25,
    48,
    52,
    47,
    53,
    72,
    62,
    63,
    63,
    67,
])

txt5 = np.array([
    40,
    130,
    101,
    171,
    200,
    183,
    173,
    192,
    188,
    171,
])

txt6 = np.array([
    25,
    87,
    94,
    206,
    290,
    305,
    160,
    111,
    135,
    112,
])

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), txt2 / 7., 'go--', linewidth=2, markersize=6, label='User 1')
plt.plot(list(range(1, 11)), txt4 / 7., 'rs-', linewidth=2, markersize=6, label='User 2')
plt.plot(list(range(1, 11)), txt5 / 7., 'b^:', linewidth=2, markersize=8, label='User 3')
plt.plot(list(range(1, 11)), txt6 / 7., 'k*-.', linewidth=2, markersize=8, label='User 4')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Daily notifications')
plt.ylim([0, 45])
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.text(4.3, 19.9, "Baseline, y=17.8", fontsize=12, backgroundcolor='w')
plt.axhline(y=17.8, color='k', linestyle='--')
plt.show()
fig.savefig("export_figures/num_notification_contextual_bandit.pdf", bbox_inches='tight')

# %%
# Online interative simulation, response rate
us = [
    0.722,
    0.598,
    0.941,
    0.818,
    0.712,
    0.886,
    0.733,
    0.633,
    0.627,
    0.765,
]

india = [
    0.706,
    0.533,
    0.594,
    0.562,
    0.636,
    0.895,
    0.926,
    0.863,
    0.927,
    0.857,
]

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), us, 'bo--', linewidth=2, markersize=6, label='User 1 (the U.S.)')
plt.plot(list(range(1, 11)), india, 'r*-.', linewidth=2, markersize=8, label='User 4 (India)')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Response rate')
plt.ylim([0.5, 1.0])
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.show()
fig.savefig("export_figures/interactive_response_rate.pdf", bbox_inches='tight')

# %%
us = np.array([
    391,
    161,
    61,
    177,
    143,
    178,
    173,
    193,
    142,
    18,
])

india = np.array([
    325,
    326,
    126,
    67,
    57,
    58,
    58,
    57,
    124,
    148,
])

fig = plt.figure(figsize=(8, 3.5))
plt.plot(list(range(1, 11)), us / 7., 'bo--', linewidth=2, markersize=6, label='User 1 (the U.S.)')
plt.plot(list(range(1, 11)), india / 7., 'r*-.', linewidth=2, markersize=8, label='User 4 (India)')
plt.legend(loc='best', ncol=2)
plt.xlabel('Time (week)')
plt.ylabel('Daily notifications')
plt.grid()
matplotlib.rcParams.update({'font.size': 14})
plt.show()
fig.savefig("export_figures/interactive_num_notification.pdf", bbox_inches='tight')
